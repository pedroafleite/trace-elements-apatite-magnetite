# %% [markdown]
# <a href="https://colab.research.google.com/github/pedroafleite/trace-elements-apatite-magnetite/blob/main/mineral_pca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
apatite = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/geochemistry/apatite_empa.csv', sep=';')
apatite.head()
# Out:
#    Sample_ID Sample     Deposit  ... U238_ppm Unnamed: 57 U238_ppm.1
# 0  B6_ap_1_1     B6  X1 deposit  ...      NaN         NaN        NaN
# 1  B6_ap_1_2     B6  X1 deposit  ...      NaN         NaN        NaN
# 2  B6_ap_2_1     B6  X1 deposit  ...    24.30         NaN      34.39
# 3  B6_ap_3_1     B6  X1 deposit  ...    27.14         NaN      44.80
# 4  B6_ap_3_2     B6  X1 deposit  ...     9.69         NaN      17.98
#
# [5 rows x 59 columns]

# %%
magnetite = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/geochemistry/geochem_mag.csv', sep=';')
magnetite.head()
# Out:
#       Sample_ID Sample                     Deposit  ... Pb_ppm  Th_ppm  U_ppm
# 0  GT-2_mag_1_1   GT-2  Pé Quente deposit (type 2)  ...   1.35  0.6900   0.25
# 1  GT-2_mag_1_2   GT-2  Pé Quente deposit (type 2)  ...    NaN     NaN    NaN
# 2  GT-2_mag_2_1   GT-2  Pé Quente deposit (type 2)  ...   0.96     NaN    NaN
# 3  GT-2_mag_3_1   GT-2  Pé Quente deposit (type 2)  ...    NaN     NaN    NaN
# 4  GT-2_mag_4_1   GT-2  Pé Quente deposit (type 2)  ...   1.30  0.0865    NaN
#
# [5 rows x 69 columns]
